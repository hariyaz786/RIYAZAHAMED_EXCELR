# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, GRU

# %%
df = pd.read_csv("monthly_milk_production.csv")

print(df.head())
print(df.columns)
# Out:
#       Date  Production
# 0  1962-01         589
# 1  1962-02         561
# 2  1962-03         640
# 3  1962-04         656
# 4  1962-05         727
# Index(['Date', 'Production'], dtype='str')

# %%
# Clean column names
df.columns = df.columns.str.strip()

# Rename columns 
df.columns = ['Month', 'Production']

# %%
df['Month'] = pd.to_datetime(df['Month'])
df.set_index('Month', inplace=True)

print(df.head())
# Out:
#             Production
# Month
# 1962-01-01         589
# 1962-02-01         561
# 1962-03-01         640
# 1962-04-01         656
# 1962-05-01         727

# %%
plt.figure()
plt.plot(df['Production'])
plt.title("Monthly Milk Production")
plt.xlabel("Year")
plt.ylabel("Production")
plt.show()

# %%
print(df.isnull().sum())
# Out:
# Production    0
# dtype: int64

# %%
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(df[['Production']])

# %%
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i+window_size])
        y.append(data[i+window_size])
    return np.array(X), np.array(y)

window_size = 12

X, y = create_sequences(data_scaled, window_size)

# %%
train_size = int(len(X) * 0.8)

X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
model_rnn = Sequential()
model_rnn.add(SimpleRNN(50, activation='relu', input_shape=(window_size, 1)))
model_rnn.add(Dense(1))

model_rnn.compile(optimizer='adam', loss='mse')
model_rnn.fit(X_train, y_train, epochs=50, batch_size=16)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0362
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0250
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0232
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0191
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0144
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0127
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0103
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0075
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0060
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0033
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0028
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0026
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.7049e-04
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.5321e-04
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.8178e-04
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9073e-04
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5494e-04
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3105e-04
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0724e-04
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.1319e-04
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.6769e-04
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3370e-04
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0828e-04
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5975e-04
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.5178e-04
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.9628e-04
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9322e-04
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8022e-04
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.6566e-04
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.2950e-04

# %%
model_lstm = Sequential()
model_lstm.add(LSTM(50, activation='relu', input_shape=(window_size, 1)))
model_lstm.add(Dense(1))

model_lstm.compile(optimizer='adam', loss='mse')
model_lstm.fit(X_train, y_train, epochs=50, batch_size=16)
# Out:
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2369
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1559
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0800
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0302
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0313
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0260
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0264
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0235
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0234
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0229
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0227
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0222
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0220
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0214
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0212
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0205
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0203
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0191
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0187
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0181
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0161
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0154
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0158
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0209
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0154
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0140
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0125
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0113
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0104
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0096
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0089
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0083
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0081
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0071
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0088
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0068
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0065
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0064
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0060
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0058
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0058
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0066
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0061
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0053
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0051
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0060
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0061
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0061
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0063

# %%
model_gru = Sequential()
model_gru.add(GRU(50, activation='relu', input_shape=(window_size, 1)))
model_gru.add(Dense(1))

model_gru.compile(optimizer='adam', loss='mse')
model_gru.fit(X_train, y_train, epochs=50, batch_size=16)
# Out:
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.2254
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1368
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0681
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0284
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0304
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0253
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0239
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0229
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0217
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0215
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0206
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0199
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0194
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0190
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0182
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0178
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0174
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0169
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0167
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0164
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0155
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0152
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0149
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0146
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0141
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0138
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0133
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0131
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0125
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0124
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0121
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0118
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0114
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0119
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0110
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0103
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0099
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0094
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0089
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0083
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0072
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0078
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0081
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0084
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0081
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0066
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0075
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0072

# %%
pred_rnn = model_rnn.predict(X_test)
pred_lstm = model_lstm.predict(X_test)
pred_gru = model_gru.predict(X_test)

# Inverse scaling
pred_rnn = scaler.inverse_transform(pred_rnn)
pred_lstm = scaler.inverse_transform(pred_lstm)
pred_gru = scaler.inverse_transform(pred_gru)

y_test_actual = scaler.inverse_transform(y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step

# %%
def evaluate(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    return rmse, mae, mape

print("RNN:", evaluate(y_test_actual, pred_rnn))
print("LSTM:", evaluate(y_test_actual, pred_lstm))
print("GRU:", evaluate(y_test_actual, pred_gru))
# Out:
# RNN: (np.float64(22.743835951770187), 18.27205085754395, np.float64(2.123449510117084))
# LSTM: (np.float64(35.006520799926335), 30.349935531616207, np.float64(3.5377436170469614))
# GRU: (np.float64(31.928538776040885), 23.108963012695302, np.float64(2.738610371358489))

# %%
plt.figure()
plt.plot(y_test_actual, label='Actual')
plt.plot(pred_lstm, label='LSTM Prediction')
plt.legend()
plt.title("Actual vs Predicted")
plt.show()

# %%
future_input = data_scaled[-window_size:]
future_output = []

for i in range(12):
    future_input_reshaped = future_input.reshape(1, window_size, 1)
    pred = model_lstm.predict(future_input_reshaped)
    
    future_output.append(pred[0][0])
    future_input = np.append(future_input[1:], pred)

future_output = scaler.inverse_transform(np.array(future_output).reshape(-1,1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step

# %%
plt.figure()
plt.plot(df['Production'], label='Original Data')
plt.plot(range(len(df), len(df)+12), future_output, label='Forecast')
plt.legend()
plt.title("Milk Production Forecast")
plt.show()
